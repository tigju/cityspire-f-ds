# %%
import pandas as pd
import pandas as pd

# %%
pop = pd.read_csv('Population.csv', encoding = 'unicode_escape', index_col=0)

# %%
pop.head()
# Out:
#                            City  ... Ten_Year_Population_Growth
# US Population Rank               ...
# 1                      New York  ...                      4.00%
# 2                   Los Angeles  ...                      7.40%
# 3                       Chicago  ...                     -6.90%
# 4                       Houston  ...                     17.30%
# 5                       Phoenix  ...                     26.60%
#
# [5 rows x 4 columns]

# %%
pop.tail()
# Out:
#                             City  ... Ten_Year_Population_Growth
# US Population Rank                ...
# 996                 Carol Stream  ...                     -3.10%
# 997                  Culver City  ...                      0.70%
# 998                        Hobbs  ...                     36.70%
# 999                     Lynnwood  ...                     15.60%
# 1000                 Mooresville  ...                    100.70%
#
# [5 rows x 4 columns]

# %%
pop.columns
# Out:
# Index(['City', 'State', '2019 Population', 'Ten_Year_Population_Growth'], dtype='object')

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 4 columns):
# City                          1000 non-null object
# State                         1000 non-null object
# 2019 Population               1000 non-null object
# Ten_Year_Population_Growth    1000 non-null object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
pop.describe()
# Out:
#                City        State 2019 Population Ten_Year_Population_Growth
# count          1000         1000            1000                       1000
# unique          926           89             993                        600
# top     Springfield   California         115,382                      0.00%
# freq              5          118               2                         14

# %%
! pip install pandas==0.25

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(pop)
profile
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
pop['City'] = pop['City'].astype(str)

# %%
pop['State'] = pop['State'].astype(str)

# %%
pop.dtypes
# Out:
# City                          object
# State                         object
# 2019 Population               object
# Ten_Year_Population_Growth    object
# dtype: object

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 4 columns):
# City                          1000 non-null object
# State                         1000 non-null object
# 2019 Population               1000 non-null object
# Ten_Year_Population_Growth    1000 non-null object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
from google.colab import files

pop.to_csv('Population_new.csv')
files.download('Population_new.csv')
